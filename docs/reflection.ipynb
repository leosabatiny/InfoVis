# %% [markdown]
# # Reflection

# %% [markdown]
# We focused on improving the clarity of our arguments in the visualizations’ captions, ensuring a balance between interactivity and interpretability, reducing overcrowded visuals by filtering key categories and countries, and restructuring the story to align more closely with reader logic.
#
# We applied design heuristics to evaluate our visual encoding choices, ensuring effective axis scaling, color-blind safe palettes, and proper chart types for each relationship.

# %% [markdown]
# ## Peer Feedback
# On June 19th, 2025, our team D4 gathered with 3 other groups for peer feedback, where one group at a time pitched the work that has been done in the past 2 weeks. Our group was last and only one group(D2) stayed to give us peer feedback. After the pitch, D2 and the TA gave feedback on what has been done well, as well as things to improve on.
#
# Below is a list of the feedback provided from D2, as well as the TAs:
# What has been done well:
# - The chosen visualisations looked great.
#     - Extra compliments for the interactive visualisation.
# - The chosen topic was interessting.
# - Bonus points for developing a webpage
#
# What we could improve:
# - The perspectives are to much alike.
# - Some visualisations could be improved upon.
#     - Choosing the right colors for each graph(Hydro should be blue, because people associate water with the color blue).
# - The data story lacks focus, making it hard for the audience to grasp the main takeaway.
#
# Just before the discussion and Peer Feedback, we came to the realisation that one of our datasets wasn't trustworthy. Right after we received the feedback, we changed our chosen perspectives and started searched for new datasets that would fit our new perspectives.

# %% [markdown]
# ## Self-reflection
# If this project lasted 1-3 weeks longer, we would have shifted our focus from Europe to the world. It would have been interessting to compare countries from different continents. We would probably keep our current visualisations and just improve upon them and add more countries.
